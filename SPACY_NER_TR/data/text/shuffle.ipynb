# %%
import pandas as pd
df = pd.read_csv('text.txt')
df1 = df.sample(len(df),random_state=29)
df1.to_csv("data.txt",index=False)

# %%
import pandas as pd
df1 = pd.read_csv("data.txt")
df2 = df1.iloc[900:1000,:]
df2.to_csv("data_7th_100.txt",index=False)
